# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %% [markdown]
# # Tasks to do on the DataSet
# Questions to answer:
#
# -> **_Survival rate_**
#
# -> **_Survival by gender_**
#
# -> **_Survival by passenger class_**

# %% [markdown]
# # Questions to Answer
# 1️⃣ What percentage of passengers survived?
#
# 2️⃣ Did women survive more than men?
#
# 3️⃣ Which passenger class survived most?
#
# 4️⃣ What is the age distribution?
#
# 5️⃣ Did expensive tickets increase survival chances?

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
na = df.loc[df["Age"].isna(), ["PassengerId"]]
print(len(na))
# Out:
# 177

# %%
df[df["PassengerId"] == 6]
# Out:
#    PassengerId  Survived  Pclass              Name   Sex  Age  SibSp  Parch  \
# 5            6         0       3  Moran, Mr. James  male  NaN      0      0
#
#    Ticket    Fare Cabin Embarked
# 5  330877  8.4583   NaN        Q

# %%
df = df.set_index("PassengerId")

# %%
survived_by_class = df.loc[df["Survived"] == 1, ["Pclass"]]

# %%
plt.hist(survived_by_class, bins=[0.5, 1.5, 2.5, 3.5], edgecolor="black", rwidth=0.8)
plt.xticks([1,2,3])
plt.show()

# %%
survived_by_age = df.loc[df["Survived"] == 1, ["Age"]]

# %%
plt.hist(survived_by_age, edgecolor="black", bins = np.arange(0, 100, 10))
plt.xticks(np.arange(0, 100, 10))
plt.show()

# %%
survived_by_gender = df.loc[df["Survived"] == 1, "Sex"].value_counts()

# %%
plt.hist(survived_by_gender, edgecolor="black")
plt.show()

# %%
survived_by_gender
# Out:
# Sex
# female    233
# male      109
# Name: count, dtype: int64

# %%
plt.bar(survived_by_gender.index, survived_by_gender.values, color=['tab:pink', 'tab:blue'], edgecolor="black")

plt.title("Survivor Count by Gender")
plt.ylabel("Number of Survivors")
plt.show()

# %%
plt.bar(df.index, )
